# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
model_name = "facebook/nllb-200-distilled-600M"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    src_lang="eng_Latn",
    tgt_lang="dan_Latn"
)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /Users/maria/projekty/RPA_projects/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/maria/projekty/RPA_projects/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
model.save_pretrained("./nllb-200-distilled-600M")
tokenizer.save_pretrained("./nllb-200-distilled-600M")
# Out:
# ('./nllb-200-distilled-600M/tokenizer_config.json',
#  './nllb-200-distilled-600M/special_tokens_map.json',
#  './nllb-200-distilled-600M/sentencepiece.bpe.model',
#  './nllb-200-distilled-600M/added_tokens.json',
#  './nllb-200-distilled-600M/tokenizer.json')
